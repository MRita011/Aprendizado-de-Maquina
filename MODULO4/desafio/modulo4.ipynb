# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Data
# https://archive.ics.uci.edu/dataset/109/wine

# %%
wines = pd.read_csv('wine.csv', index_col=False)
wines
# Out:
#      class  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0        1    14.23       1.71  2.43               15.6        127
# 1        1    13.20       1.78  2.14               11.2        100
# 2        1    13.16       2.36  2.67               18.6        101
# 3        1    14.37       1.95  2.50               16.8        113
# 4        1    13.24       2.59  2.87               21.0        118
# ..     ...      ...        ...   ...                ...        ...
# 173      3    13.71       5.65  2.45               20.5         95
# 174      3    13.40       3.91  2.48               23.0        102
# 175      3    13.27       4.28  2.26               20.0        120
# 176      3    13.17       2.59  2.37               20.0        120
# 177      3    14.13       4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %% [markdown]
# ## Features
#
# - Class: target
# - Alcohol
# - Malic acid
# - Ash
# - Alcalinity of ash
# - Magnesium
# - Total phenols
# - Flavanoids
# - Nonflavanoid phenols
# - Proanthocyanins
# - Color intensity
# - Hue
# - OD280/OD315 of diluted wines
# - Proline

# %% [markdown]
# # visualize data

# %%
import seaborn as sns

# %%
sns.heatmap(wines.isnull())
# Out:
# <Axes: >

# %% [markdown]
# sem valores faltantes

# %%
sns.heatmap(wines.corr())
# Out:
# <Axes: >

# %% [markdown]
# A classe tem correlacoes acima de 0.7 com  as variaveis:
# - OD280/OD315 of diluted wines
# - Total_phenols
# - Flavanoids

# %%
wines['class'].value_counts()
# Out:
# class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %% [markdown]
# classes perto de serem balanceadas (sem muita diferenca entre elas nas amostras)

# %% [markdown]
# # Preparando os dados

# %%
data = wines.drop(['class'], axis=1)
data
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23       1.71  2.43               15.6        127           2.80
# 1      13.20       1.78  2.14               11.2        100           2.65
# 2      13.16       2.36  2.67               18.6        101           2.80
# 3      14.37       1.95  2.50               16.8        113           3.85
# 4      13.24       2.59  2.87               21.0        118           2.80
# ..       ...        ...   ...                ...        ...            ...
# 173    13.71       5.65  2.45               20.5         95           1.68
# 174    13.40       3.91  2.48               23.0        102           1.80
# 175    13.27       4.28  2.26               20.0        120           1.59
# 176    13.17       2.59  2.37               20.0        120           1.65
# 177    14.13       4.10  2.74               24.5         96           2.05
#
# ...

# %% [markdown]
# ## Normalizacao

# %%
X = (data - data.min())/(data.max() - data.min())
X
# Out:
#       Alcohol  Malicacid       Ash  Alcalinity_of_ash  Magnesium  \
# 0    0.842105   0.191700  0.572193           0.257732   0.619565
# 1    0.571053   0.205534  0.417112           0.030928   0.326087
# 2    0.560526   0.320158  0.700535           0.412371   0.336957
# 3    0.878947   0.239130  0.609626           0.319588   0.467391
# 4    0.581579   0.365613  0.807487           0.536082   0.521739
# ..        ...        ...       ...                ...        ...
# 173  0.705263   0.970356  0.582888           0.510309   0.271739
# 174  0.623684   0.626482  0.598930           0.639175   0.347826
# 175  0.589474   0.699605  0.481283           0.484536   0.543478
# 176  0.563158   0.365613  0.540107           0.484536   0.543478
# 177  0.815789   0.664032  0.737968           0.716495   0.282609
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0         0.627586    0.573840              0.283019         0.593060
# ...

# %%
y = wines['class']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: class, Length: 178, dtype: int64

# %% [markdown]
# # Split train test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =  train_test_split(X, y, test_size=.2, random_state=42)

# %% [markdown]
# # Criando o modelo

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
param_grid = {
    'C': [1e-1, 1, 1e1, 1e2, 1e3],
    'gamma': [1, 1e-1, 1e-2, 1e-3, 1e-4],
    'kernel': ['poly', 'rbf', 'sigmoid']
}

# %%
grid = GridSearchCV(SVC(), param_grid)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10.0, 100.0, 1000.0],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['poly', 'rbf', 'sigmoid']})

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'poly'}

# %% [markdown]
# # Validando o modelo

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_hat = grid.predict(X_test)

# %%
print(confusion_matrix(y_test, y_hat))
# Out:
# [[14  0  0]
#  [ 0 14  0]
#  [ 0  0  8]]

# %%
print(classification_report(y_test, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# # Criando modelo com todos os dados

# %%
data
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23       1.71  2.43               15.6        127           2.80
# 1      13.20       1.78  2.14               11.2        100           2.65
# 2      13.16       2.36  2.67               18.6        101           2.80
# 3      14.37       1.95  2.50               16.8        113           3.85
# 4      13.24       2.59  2.87               21.0        118           2.80
# ..       ...        ...   ...                ...        ...            ...
# 173    13.71       5.65  2.45               20.5         95           1.68
# 174    13.40       3.91  2.48               23.0        102           1.80
# 175    13.27       4.28  2.26               20.0        120           1.59
# 176    13.17       2.59  2.37               20.0        120           1.65
# 177    14.13       4.10  2.74               24.5         96           2.05
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: class, Length: 178, dtype: int64

# %%
modelo = SVC(C=0.1, gamma = 1, kernel = 'poly')

# %%
modelo.fit(data, y)
# Out:
# SVC(C=0.1, gamma=1, kernel='poly')
